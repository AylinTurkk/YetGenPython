# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
import time
def vkiHesaplama(kilo,boy):
    vki = kilo/(boy**2)
    return round(vki,1)

def degerAralıgı(vki):
    if vki<18.5:
        return("Zayıf")
    elif vki<=24.9:
        return("Normal Kilolu")
    elif vki<=29.9:
        return("Fazla Kilolu")
    elif vki<=39.9:
        return("Obez")
    elif vki>40:
        return("Morbid Obez")

def ciktiOlustur(isim,yas,kilo,boy,vki,deger):
    kayitTarihi = time.ctime(time.time())

    t1 = f"kullanıcı adi {isim}\n"
    t2 = f"Kullanıcın yaş, kilo, boy bilgisi {yas},{kilo},{boy}\n"
    t3 = f"Kullanıcının vücut kitle indeksi {vki}\n"
    t4 = f"Değer aralığı {deger}\n"
    t5 = f"Oluşturma tarihi {kayitTarihi}\n"

    output = t1+t2+t3+t4+t5
    return output
    
def main():
    girisSayisi = int(input("Kaç giriş yapacaksınız?"))

    for i in range(girisSayisi):
        print(f"Kullanıcı kaydı {i+1}")
        isim = input("İsim-Soyisim giriniz:")
        yas = int(input("Yaşınızı giriniz:"))
        kilo = float(input("Kilonuzu giriniz (kg):"))
        boy = float(input("Boyunuzu giriniz (m):"))
        vki = vkiHesaplama(kilo,boy)
        deger = degerAralıgı(vki)
        output = ciktiOlustur(isim,yas,kilo,boy,vki,deger)

        with open("saglık.txt","a",encoding="utf-8") as file:
            file.write(output)
            file.write("*"*20)
            file.write("\n")
            print("kullancı kaydedildi.")
    print("Veriler 'saglık.txt' dosyasına kaydedildi.\n")
main()
# Out:
# Kullanıcı kaydı 1
# kullancı kaydedildi.
# Kullanıcı kaydı 2
# kullancı kaydedildi.
# Veriler 'saglık.txt' dosyasına kaydedildi.

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
import time
menu = {
        "elma" :0.50,
        "armut" :0.75,
        "kivi" :1.0,
        "portakal" :0.75,
        "mango" :1.50,
        "kavun" :1.35
}

def displayMenu():
    print("------YETBAR MENU------")
    for item in list(menu.keys()):
        print(f"{item.upper():<10} : {menu.item} TL")

def tekUrunFiyatHesaplama(urun,adet):
    assert adet>=0 , "Ürün adedi 0 veya daha küçük olamaz."
    if urun not in list(menu.keys()):
        return None
    else:
        return menu[urun]*adet

def satinAlma():
    displayMenu()
    print("Satın almak istediğiniz ürünü giriniz. Çıkış yapmak için 0 tuşlayınız.")
    satinAlinanUrunler=[]
    urunAdedi=[]
    sonFiyat=0

    while 1:
        eklenecekUrun = input("Eklemek istediğiniz ürün:")
        if eklenecekUrun == 0:
            print("Fiş kaydediliyor.")
            break
        eklemeAdedi = int(input("Kaç adet eklemek istiyorsunuz?"))
        fiyat = tekUrunFiyatHesaplama(eklenecekUrun,eklemeAdedi)

        if fiyat is None :
            "Yanlış bir giriş yaptınız. Ürün eklenemedi."
        else:
            print(f"Satın alma ücreti: {fiyat}.\nSatın almayı onaylamak için 'o' iptal etmek için 'i' tuşlayınız." )
            check = input("Satın almayı onaylıyor musunuz?")
            if check =="o":
                print("Satın alma onaylandı.")
                print("-"*40)
                sonFiyat+=fiyat
                satinAlinanUrunler.append(eklenecekUrun)
                urunAdedi.append(eklemeAdedi)
                print(f"Ara toplam: {sonFiyat}")
            elif check == i:
                print("Satın alma işlemi iptal edildi.")
                print("-"*40)

def main():
    print("YetBar'a hoş geldiniz!\nMenüyü görüntülemek için '1'e,smoothie yapmak için '2'ye, çıkmak için '0' a basınız.")
    program = None
    while 1 :
        program=int(input("Tercihiniz:"))
        if program<0 or program>2:
            print("Yanlış bir tercih yaptınız.\nTekrar deneyiniz.")

        elif program==0:
            print("Çıkış yapıldı. iyi günler dileriz.")
        elif program ==1:
            displayMenu()
        elif program==2:
            satınAlmaUcreti, satinAlinanUrunler, urunAdedi = satinAlma()

            with open("kasa.txt","a",encoding="utf-8") as file:
                file.write(str(time.ctime(time.time())))
                file.write("\n")
                file.write(",".join(map(str,satinAlinanUrunler)))
                file.write("\n")
                file.write(",".join(map(str,urunAdedi)))
                file.write("\n")
                file.write(f"Toplam: {satınAlmaUcreti}")
                file.write("\n")
                file.write("*"*20)
                file.write("\n")
            
            cikisKontrol = input("Başka bir işlem yapmak istiyor musunuz? (evet/hayır)")
            if cikisKontrol=="evet":
                pass
            else:
                print("\n\nTesekkurler")
                break
